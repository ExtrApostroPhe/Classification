# %% [markdown]
# <a href="https://colab.research.google.com/github/ExtrApostroPhe/Classification/blob/main/Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import jieba
import re
import nltk
import ssl
import os

import pandas as pd
from google.colab import drive
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Dense, MaxPool1D, Flatten, Input, Dropout, Embedding
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.layers import BatchNormalization
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
lemmatizer = WordNetLemmatizer()
nltk.download('stopwords')
nltk.download('wordnet')
stw = set(stopwords.words('english'))
drive.mount('/content/drive', force_remount=True)  
os.chdir('/content/drive/My Drive/news_ipm')

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Mounted at /content/drive

# %%
data_env = pd.read_csv('./train_data/environment.txt', header = None, sep = "\n")  # 这里只获取部分数据
data_health = pd.read_csv('./train_data/health.txt', header = None, sep = "\n")
data_hk = pd.read_csv('./train_data/hk_macao.txt', header = None, sep = "\n")
data_inno = pd.read_csv('./train_data/innovation.txt', header = None, sep = "\n")
data_military = pd.read_csv('./train_data/military.txt', header = None, sep = "\n")
data_notional = pd.read_csv('./train_data/notional_affairs.txt', header = None, sep = "\n")
data_society = pd.read_csv('./train_data/society.txt', header = None, sep = "\n")

data_env[1] = 0
data_health[1] = 1
data_hk[1] = 2
data_inno[1] = 3
data_military[1] = 4
data_notional[1] = 5
data_society[1] = 6
dataset = pd.concat([data_env, data_health, data_hk, data_inno, data_military, data_notional, data_society ], 
                    axis = 0, 
                    ignore_index = True).astype(str)
X = dataset[0]
Y = dataset[1]
print(X)
# Out:
# 0        Volunteer work sees 78.1b trees planted in China
# 1         After heavy snow, humans take food to antelopes
# 2       Key meeting stresses proper understanding of C...
# 3             China releases rare fish into Yangtze River
# 4       China makes notable progress in water, soil co...
#                               ...
# 2655    Chinese mainland reports 47 locally transmitte...
# 2656        Lhasa group to help preserve Tibetan art form
# 2657                     Nation aims to narrow wealth gap
# 2658           Capital Airport boosts Olympic precautions
# 2659              Nation strengthens grassroots democracy
# Name: 0, Length: 2660, dtype: object

# %%
def insert_text():
    X_temp = []
    for x in X:
        X_temp.append(x)
    return X_temp

def filter_text(text):
    str = re.sub('[^a-zA-Z]', ' ', text)
    return re.sub(r'\s+', ' ', str)

def lower_text(text):
    return text.lower()

def lemmatization_text(text_cut_list):
    wnl = WordNetLemmatizer()
    return [wnl.lemmatize(n) for n in text_cut_list]

def text_cut(text):
    return re.findall('[a-zA-z]+', text)

def stopwords_text(text_cut_list):
    Stop_Word_list = stopwords.words("english")
    return [n for n in text_cut_list if n not in Stop_Word_list and len(n)>=3]

article = insert_text()
X = []
print(article)
for content in article:
    content = filter_text(content)
    content = lower_text(content)
    print(content)
    word_cut = lemmatization_text(text_cut(content))
    word_cut = stopwords_text(word_cut)
#     print(word_cut)
    content = ''
    for w in word_cut:
        content = content + w + ' '
    X.append(content)
    # print(content)

# print(X)
# print(Y)
# Out:
# ['volunteer work see tree planted china ', 'heavy snow human take food antelope ', 'key meeting stress proper understanding china carbon neutrality goal ', 'china release rare fish yangtze river ', 'china make notable progress water soil conservation ', 'giant panda bounce back thanks reforestation ', 'ecological corridor help expand giant panda habitat ', 'migratory bird seen yinchuan ', 'beijing look forward end heavily polluted day ', 'wetland protection reaps rich reward ', 'team assist bird search food ', 'rare bird spotted china nature reserve ', 'chinese researcher discover new wild orchid specie ', 'country vow water cooperation ', 'migratory flamingo winter bird shanxi ', 'action plan improve rural living condition ', 'china top court clarify biodiversity protection law ', 'inspection focus high emission project ', 'beijing see increasing migratory bird winter ', 'inspection uncovers soe violation ', 'complex cure key curbing desertification ', 'beijing expects avian guest winter ', 'scientist urge better monitoring glacier ', 'benefit flowing plan river basin protection ', 'generation effort protect china second largest freshwater lake ', 'king monkey make furry friend forest ', 'top court urge judicial support river basin protection ', 'nation eye action plan methane emission ', 'china severely punish environmental law violation key river basin ', 'firm pay yuan damage nature ', 'court ordered crack harder river polluter illegal sand miner ', 'china vow soon set working group climate action ', 'ministry lauds progress securing compensation environmental damage ', 'china coastal city combat invasive plant ', 'coal rich ordos setting green pace ', 'bri project given green emphasis ', 'wild bird flock ningxia yinhe bay ', 'new legislation protect wintering bird major freshwater lake ', 'china leading way carbon capture technology report ', 'supervision private investment environmental project stepped ', 'livestock plant resource survey track ', 'trip suzhou finding peace healing power nature ', 'nearly rare fish fry released yangtze river tributary ', 'rule cut groundwater exploitation ', 'innovation crucial achieving carbon goal ', 'china aim safeguard groundwater new rule ', 'expert china play important role tackling climate change ', 'snow leopard roam hydropower station ', 'forum brings energy expert green transition ', 'china installed capacity renewable power top ', 'shoreline restored protect ecology ', 'eliminating wild boar tricky problem ', 'eco civilization flourish vision ', 'china responsible apec forest increase ', 'nation facilitate green growth ', 'community conservation lead way yunnan noah ark ', 'gansu new energy help power province ', 'private sector urged contribute green drive ', 'hive activity aid survival ', 'nation seek counter effect rising sea level ', 'high hope greener supply chain ', 'efficient use energy key carbon goal ', 'shopping spree new battlefield reduce carbon ', 'china raise environmental awareness among young student ', 'china matching green word action ', 'nation need improve energy use efficiency phase coal ', 'single day shopping gala feature green consumption ', 'china civil aviation achieves progress reducing emission ', 'endangered fish released xinjiang major lake ', 'beijing washington sign joint climate declaration ', 'circular aim percent cut ', 'nov online shopping spree get greener ', 'international wetland meeting scheduled wuhan ', 'chilly winter due global warming expert ', 'help nation drive toward climate goal ', 'expert criticize carbon price plan ', 'climate resilient investment pay ', 'china host cop meeting convention wetland ', 'high speed rail cut greenhouse gas emission ', 'cold snap hit southern northeastern area ', 'report recommends heavy investment climate resistant infrastructure ', 'many migratory bird making stop ningxia ', 'youth take lead climate summit ', 'ruicheng fortune rise sun ', 'china issue circular control pollution ', 'first snow season ...
# volunteer work see tree planted china
# heavy snow human take food antelope
# key meeting stress proper understanding china carbon neutrality goal
# china release rare fish yangtze river
# china make notable progress water soil conservation
# giant panda bounce back thanks reforestation
# ecological corridor help expand giant panda habitat
# migratory bird seen yinchuan
# beijing look forward end heavily polluted day
# wetland protection reaps rich reward
# team assist bird search food
# rare bird spotted china nature reserve
# chinese researcher discover new wild orchid specie
# country vow water cooperation
# migratory flamingo winter bird shanxi
# action plan improve rural living condition
# china top court clarify biodiversity protection law
# inspection focus high emission project
# beijing see increasing migratory bird winter
# inspection uncovers soe violation
# complex cure key curbing desertification
# beijing expects avian guest winter
# scientist urge better monitoring glacier
# benefit flowing plan river basin protection
# generation effort protect china second largest freshwater lake
# king monkey make furry friend forest
# top court urge judicial support river basin protection
# nation eye action plan methane emission
# china severely punish environmental law violation key river basin
# firm pay yuan damage nature
# court ordered crack harder river polluter illegal sand miner
# china vow soon set working group climate action
# ministry lauds progress securing compensation environmental damage
# china coastal city combat invasive plant
# coal rich ordos setting green pace
# bri project given green emphasis
# wild bird flock ningxia yinhe bay
# new legislation protect wintering bird major freshwater lake
# china leading way carbon capture technology report
# supervision private investment environmental project stepped
# livestock plant resource survey track
# trip suzhou finding peace healing power nature
# nearly rare fish fry released yangtze river tributary
# rule cut groundwater exploitation
# innovation crucial achieving carbon goal
# china aim safeguard groundwater new rule
# expert china play important role tackling climate change
# snow leopard roam hydropower station
# forum brings energy expert green transition
# china installed capacity renewable power top
# shoreline restored protect ecology
# eliminating wild boar tricky problem
# eco civilization flourish vision
# china responsible apec forest increase
# nation facilitate green growth
# community conservation lead way yunnan noah ark
# gansu new energy help power province
# private sector urged contribute green drive
# hive activity aid survival
# nation seek counter effect rising sea level
# high hope greener supply chain
# efficient use energy key carbon goal
# shopping spree new battlefield reduce carbon
# china raise environmental awareness among young student
# china matching green word action
# nation need improve energy use efficiency phase coal
# single day shopping gala feature green consumption
# china civil aviation achieves progress reducing emission
# endangered fish released xinjiang major lake
# beijing washington sign joint climate declaration
# circular aim percent cut
# nov online shopping spree get greener
# international wetland meeting scheduled wuhan
# chilly winter due global warming expert
# help nation drive toward climate goal
# expert criticize carbon price plan
# climate resilient investment pay
# china host cop meeting convention wetland
# high speed rail cut greenhouse gas emission
# cold snap hit southern northeastern area
# report recommends heavy investment climate resistant infrastructure
# many migratory bird making stop ningxia
# youth take lead climate summit
# ruicheng fortune rise sun
# china issue circular control pollution
# first snow season hit beijing
# china continues issue orange alert blizzard
# yangtze delta region growth gain speed
# beijing issue yellow alert heavy air pollution
# guardian tibetan antelope
# egret dance amid sunset glow suqian
# top scientist discus carbon governance world laureate forum
# unfair blame climate crisis developing country medium
# china fast track cut energy consumption intensity
# beijing tianjin hebei central green effort
# country honor word climate
# expert discus dual carbon governance wla panel
# president pledge fighting climate change
# clean heating power china green development endeavor
# ministry strives create biodiversity
# crested ibis make comeback
# graphic china effort fighting climate change
# household use clean energy heating ministry
# tree served dinosaur food found yunnan
# china submits key document tackling climate change
# tuskless elephant wake call
# chinese court improve trial case involving environmental concern
# goal carbon peaking neutrality
# court urged wade river fishing issue
# white paper detail country low carbon effort
# china green energy transformation enormous white paper say
# rare animal spotted china nature reserve
# white paper elaborates china initiative tackling climate change
# china take key measure climate change white paper
# white paper reveals china principle tackling climate change
# full text responding climate change china policy action
# white paper list china achievement responding climate change
# china issue white paper response climate change
# action plan set realize climate goal
# china release action plan carbon dioxide peaking
# china release action plan peak carbon dioxide emission
# national park project qinling mountain receives approval
# gep accounting help promote environmental awareness
# new center study carbon policy
# report outline threat climate change
# housing regulator push green effort
# five criterion national park revealed
# national housing body vow green measure
# air pollution spike beijing monday
# nature conservation festival get underway shanghai
# full text working guidance carbon dioxide peaking carbon neutrality full faithful implementation new development philosophy
# policy unveiled set advance carbon goal
# waste sorting work get major push
# china make progress solid waste treatment
# lead ecological protection yellow river
# ipr case increase technology develops
# china issue guideline green development urban rural area
# five national park serve classroom
# natural resource report issued govt
# rare white plant found chongqing
# tibet get four new national level wildlife observation station
# china largest saltwater lake see water area expand
# china release comprehensive dataset permafrost qinghai tibet plateau
# guideline set biodiversity goal
# courier promote green tape free packaging
# heaven migrant bird
# weather modifier make city wetter wealthier
# china issue guideline biodiversity protection work
# country learn china experience
# photograph capture living wonder nature
# afforestation general devoted greening hometown
# thousand migrant bird flock inner mongolia lake
# nation learn china biodiversity effort
# optimism high first phase cop end
# million year old red stone forest glow vibrant life
# nation rein rapid emission growth
# vision ecological civilization provides solution global crisis
# migration path eased wild animal
# chinese strategy offer hope tackling biodiversity loss
# china first national park guard wildlife
# seed bank provide vital lifeline future
# five national park unveiled china
# provincial model may provide global boost conservation
# sky clear qinshui greening attracts tourist
# yunnan initiative help preserve rare flora
# china commit leading climate action
# china biodiversity conservation number
# china group national park announced
# biodiversity enriched yellow river estuary
# china release implementation plan achieve carbon goal
# yunnan natural choice event
# cop kick china kunming
# need know cop
# cop kick china kunming ecological civilization spotlight
# outline protect yellow river basin
# china share idea building eco friendly world
# convention chief recognizes china role eco civilization
# china eye biodiversity framework
# underground solution help clean river
# vision governance global biodiversity
# biodiversity conservation china number
# thought ecological civilization inspires world build harmony among
# china biodiversity conservation effort forge thriving ecosystem
# hong kong invest climate change mitigation next year
# report show richness new specie yunnan
# nation tightens forestry management
# white paper highlight biodiversity experience
# video chinese way biodiversity conservation
# china improves biodiversity governance white paper
# china achieves remarkable result fulfilling biodiversity obligation white paper
# china launch extensive bilateral multilateral cooperation biodiversity white paper
# china boost bri cooperation mechanism green development white paper
# china achieves remarkable result pollution control white paper
# china step south south cooperation biodiversity conservation white paper
# china contributes world green area growth white paper
# habitat wild animal keep expanding china white paper
# protected area account china land area white paper
# china take lead propose implement red line strategy ecological conservation white paper
# china contributes world new plant variety past decade white paper
# china aim win win result biodiversity conservation high quality development white paper
# china firmly support multilateral biodiversity governance system white paper
# china biodiversity conservation pursues harmony humanity nature white paper
# chinese culture profound understanding biodiversity white paper
# china issue white paper biodiversity conservation
# heavy rain trigger alert national day holiday
# opportunity emerge low carbon transition
# milu deer held example conservation
# flood control emergency response launched around yellow river
# carbon cut pollution policy focus
# china tibet spends ecological protection
# china bolster biodiversity conservation dialogue
# country reservoir secured reinforced
# extreme weather event challenge city management
# kunming ready host key biodiversity meeting
# saihanba forest farm china win honor
# yangtze conservation spotlight ahead cop
# china making great progress development goal
# eighth kubuqi international desert forum kick
# elephant canteen open keep giant wandering
# china see historic change eco environment white paper
# china asean mangrove conservation network set southwest china
# event series focus biodiversity
# takin spotted china nature reserve
# beijing see best air quality first eight month
# bohai bay offshore oil field mark power milestone
# china renews blue alert rainstorm
# solar power station light inner mongolia mining town
# tsinghua unveils institute carbon neutrality
# china set global example meeting biodiversity goal
# kunming plan host safe green intelligent cop
# jilin hunter turned ranger pas forest knowledge new generation
# hydrogen station drive greener olympics
# ingenuity lift migrating fish dam
# credit resource going green project china
# central china wuhan build wetland park year
# population przewalski horse xinjiang increase
# green sea turtle head hainan release
# measure aim limit plastic waste pollution
# china unveils year plan control plastic pollution
# yunnan like fairyland earth viral video
# global smart grid may key curbing biodiversity loss new book say
# guideline look curb plastic waste boost recycling
# low carbon path energy industry emphasized
# shanghai take step cope latest typhoon
# philosophy green growth taken root
# inspection uncovers ecological violation miner
# climate envoy link tech carbon goal
# china issue guideline deepening reform eco compensation mechanism
# eye post global biodiversity framework
# cop news center launch website ahead october conference
# preparation cop full swing kunming
# elephant return epic journey
# nation vow proactive contribution progress
# wandering elephant epic journey end
# china mull guideline biodiversity conservation
# list protected plant double
# china major contributor green development
# china planning guideline biodiversity conservation
# environmental council annual general meeting begin
# pilot direct trading green power launched
# china launch pilot scheme green power trading
# inner mongolia first institute carbon neutrality established ordos
# china renews yellow alert rainstorm
# stress achieving harmony humanity nature
# urge intensified work environment
# tibet grass plantation improve livelihood
# chinese vice premier meet climate envoy via video link
# prefecture jilin greets migrating bird
# standard carbon emission accounting system goal working group
# china launch offshore storage project
# heavy rain tipped northern area
# village aim low carbon one house time
# greenhouse gas data help craft emission cutting plan
# survey nation getting greener decade
# marine impact climate change watch
# decoding china green miracle saihanba
# china properly handle covid medical waste sewage
# submission biodiversity case study good practice sought
# bohai pollution effort rewarded cleaner sea
# rare baby leaf monkey born guangzhou
# people opting low carbon travel
# china launch new round environmental inspection
# water outflow china sanjiangyuan rise
# technology meet nature shennongjia
# baiyangdian lake reflects green development xiong
# siberian tiger dig claw reversing decline
# antarctic plankton absorbing carbon dioxide study find
# tibetan antelope population rebound
# firm action needed tackle threat posed climate change
# app point way green lifestyle
# forest authority help country reach climate goal
# cop hosted two phase
# china restore million hectare degraded grassland
# report find extreme weather set rise global temperature
# retired patrolman devoted protecting forest
# china sharpens legal weapon fight noise pollution
# emission quota tackle air pollution
# ozone balancing power ecological equilibrium
# restoration effort turn polluted park green jewel
# shenzhen set temporary protection area whale
# china report across board improvement eco environment
# helping hand guide roaming elephant home
# china carbon market running smoothly ministry
# nearly yangtze finless porpoise detected china poyang lake
# china deliberates law revision prevent control noise pollution
# police stringently crack crime threatening yellow river environment
# china produce first global carbon flux dataset
# unique study aid effort protect gibbon
# record low density seen hebei
# endangered big cat recorded jilin
# green sanming paradise bird
# hebei saw record low density july
# fry release fishing ban help yangtze stock rise
# yunnan forest home large population gibbon
# senior set sight law degree
# low impact lishu model step protection precious black soil
# beautiful bird symbol good luck nobility ancient china
# warning signal endangered bird
# china boost effort hit green target
# tibetan antelope quite endangered anymore
# china becoming greener faster country say bbc
# first cross border carbon trade xiong
# elephant heading home month wandering
# nation well way greener future
# china bigger role offering vaccine stressed
# anti desertification push xinjiang show promise
# warming lead higher precipitation variability study
# extreme weather event rising china blue paper
# dirty shirt uneven road headscarf enter plateau history
# control resource becomes top priority
# population milu deer increasing due conservation effort
# china report rising vegetation coverage better ecoclimate blue paper
# hot weather forecast continue ahead next typhoon
# major hydropower station yangtze river generates kwh clean energy
# new study shed light plant adaptability high altitude
# call unity himalayan region
# nation see result effort revive marine life
# lower albedo drive glacier melting qinghai tibet plateau study
# cop endangered orchard found longling county
# beijing lift blue alert rain flooding
# chongqing get world heritage site
# qingdao forum survey standardization development
# ministry take control two marine satellite
# lhasa take wildlife protection seriously
# man quest protect endemic specie
# inspection target high energy project
# china continues transport shift railway curb pollution
# typhoon shutter shanghai transport storm hit
# expert explain cause duration rainstorm
# global carbon dioxide level set record
# killed heavy rain china zhengzhou
# shaanxi legislative effort seek protect yellow river ecosystem
# high carbon project inspector sight
# earth cryosphere shrink rapidly due global warming study
# elephant hit muddy pond escape summer heat
# china qinghai restores hectare desertified land
# expert focus biodiversity cop approach
# beijing olympics competition zone see improving air quality
# success saving finless porpoise display
# thousand trained new role
# former logger branch protect local woodland animal
# new snake specie found northwest china qinling mountain
# beijing keep boosting number energy efficient project
# rare shimmering ibis spotted hubei
# china full throttle green energy transition achieve carbon neutrality
# coastal bird sanctuary world heritage candidate
# commitment honored
# wild animal thrive environment improves
# tibet launch survey fishery resource
# eco forum global kick southwest china
# alert heavy downpour across nation
# china boost marine habitat protection
# beijing report fine air quality record june
# mariner went help whale
# four rescued whale released
# panda rise show biodiversity improving
# rescued tibetan antelope released wild hoh xil
# china make notable progress biodiversity conservation official
# chinese vice premier urge eco conservation yellow river basin
# eco forum focus low carbon transition
# omicron variant confirmed guangzhou
# expert call greater awareness severe skin disease
# zhejiang beef nucleic acid test
# china poised eliminate hepatitis
# township dongguan move contain virus
# mainland report first case covid omicron variant
# chinese mainland report new local case
# condition conquered helping hand
# new hope offered rare disease patient
# port city asked step virus control effort
# chinese mainland report locally transmitted covid case
# china ramp epidemic control land port city
# article blaming seafood market virus lack credibility
# china zhejiang report local covid case
# govt tightens measure port city curb virus
# china expected reach herd immunity year end
# chinese fully vaccinated covid
# chinese mainland report locally transmitted covid case
# cross provincial settlement make patient healthcare convenient
# china bone marrow bank facilitates donation
# cross provincial settlement medical fee cover entire china
# china lower cost covid nucleic acid test
# antibody combination therapy approved treat covid
# two chinese covid medicine receive emergency approval
# chinese mainland report locally transmitted covid case
# yangtze river delta see virus case
# campaign curb medical insurance fraud rake billion yuan
# nanjing record one new covid case
# new drug found kill senescent cell mouse extend lifespan
# chinese mainland report locally transmitted covid case
# new covid case reported ningbo
# appeal never fade ancient therapy remains fresh attractive
# drug added national insurance list
# ningbo report three covid infection
# north china border city report locally transmitted covid case
# covid vaccine administered chinese mainland
# chinese mainland report locally transmitted covid case
# china harbin add risk area covid case rise
# china stick strict anti virus policy omicron rage
# emergence omicron vindicates china appoarch prevention
# chinese mainland report locally transmitted covid case
# manzhouli tightens border control measure
# question mask sterilization
# new covid case reported capital although situation control
# beijing report positive case
# china pushing development vaccine omicron
# china stick strategy virus response
# yunnan make stride ending disease
# effort urged curb hiv aid
# world aid day marked across china
# covid case reported inner mongolia
# omicron variant isolated hku team asia first
# chinese mainland report locally transmitted covid case
# resident tibet covered insurancebasic medical
# china launch step tackle omicron variant
# china frequent test strengthen covid containment official
# know omicron variant
# china strategy cope omicron
# omicron variant pose fresh viral threat
# inner mongolia record one new locally transmitted confirmed case
# chinese mainland report locally transmitted covid case
# stronger partnership needed zero malaria
# insulin added bulk buy drug program
# covid vaccine administered chinese mainland
# bln covid vaccine administered chinese mainland
# chinese mainland report locally transmitted covid case
# four shanghai hospital resume normal service
# tcm discussed consultation session
# new case city dined restaurant
# shanghai hangzhou report new covid case
# xuzhou report asymptomatic covid case
# railway freight handler tackle virus threat border
# government action plan promotes breastfeeding
# tcm therapy recognized bri country
# child get dosage adult
# chinese anti covid drug candidate enter human trial
# safety first ruili school student
# china anti covid drug enters late stage human trial
# chinese antibody drug show promise trial
# latest virus outbreak final stage
# covid vaccine administered chinese mainland
# china latest covid resurgence enters final stage official
# total bln people china vaccinated covid
# chinese experimental drug cut hospital stay
# ruili increase covid testing capacity
# nation china new covid treatment
# china help international vaccine drive
# shanghai launch covid vaccination child aged
# new drug show promise treating covid
# chinese mainland report locally transmitted covid case
# beijing heightens covid control
# chinese mainland report locally transmitted covid case
# dalian get control covid
# bln covid vaccine administered chinese mainland
# chinese mainland report locally transmitted covid case
# dalian start citywide covid testing
# strategy containing virus prof effective
# chinese mainland report locally transmitted covid case
# mainland report new local case
# china stick strict containment measure say health body
# zero case month tibet continues widening covid vaccination
# epidemiologist urge booster shot public
# covid vaccine administered chinese mainland
# beijing find similarity case genome sequencing covid virus
# correct practice prevent virus parcel
# beijing tightens measure new infection cluster reported
# expert new antiviral drug show promise covid
# delivery service suspended hebei city new covid case
# barefoot doctor safeguard health villager
# china develop national level regional facility
# partnership benefit medical center
# china include screening depression student health check
# tianjin binhai area vaccinates foreign child
# new case top one month
# china new covid drug showing good result
# dalian take measure prevent outbreak spread
# explainer space time contact
# new local covid infection attributable overseas source
# strict virus control measure continue say national health body
# around million booster shot already delivered
# goal set lower infant mortality rate
# china vow shore county level hospital
# china injects confidence impetus global covid response
# medical expert scientist call greater equality healthcare access
# medical expert call info sharing
# insurance reform aid access medicine
# booster shot recommended
# six people chongqing test positive covid
# wider vaccination help china build immune barrier coronavirus
# local covid case reported chengdu
# guangdong build new multiuse infectious disease ward
# chinese mainland report locally transmitted covid case
# outbreak expected contained month
# beijing report covid family cluster
# expert say tough anti virus policy expensive
# new case reported chaoyang school
# cigarette attracting teenager report say
# capital tightens measure virus control
# beijing stepping testing requirement key industry
# shanghai disney find case far testing
# vigilance virus urged winter nears
# heilongjiang case linked inner mongolia say national health body
# three domestic vaccine get green light child
# china latest covid resurgence spread province health official
# people china complete covid vaccination
# zhong china contain covid resurgence within month
# northwest china city start fifth round nucleic acid testing
# china inner mongolia report new local covid case
# universal beijing enters state emergency large gathering curbed capital
# china dispatch covid working group province
# shanghai begin vaccinating booster
# guangdong provide free hpv vaccine
# beijing start covid vaccination child aged
# medical team fight gansu virus outbreak
# hpv shot expected benefit world
# covid vaccine administered chinese mainland
# heilongjiang city report new covid case
# beijing covid case share transmission chain
# capital prioritizes student safety new outbreak
# beijing neighborhood undergoes covid testing lockdown
# prepared high incidence covid flu
# chinese mainland report locally transmitted covid case
# inner mongolia ejine conduct fifth round covid testing
# chinese province offer covid jab child aged
# chinese vaccine help global covid fight
# myopia rate among young student decline
# covid vaccine administered chinese mainland
# nucleic acid testing center told deliver result faster
# vaccination young child begin around country
# chinese mainland report locally transmitted covid case
# watch briefing china covid assistance intl
# hospital school bring hope health amid adversity
# authority strive comfort stranded tourist
# chinese learning using traditional chinese medicine
# covid booster shot
# official urged mull booster shot capability
# covid outbreak hit nation
# air inflated testing lab covid enters operation china gansu
# china inner mongolia add local covid case
# new case beijing linked inner mongolia
# expert warns flu case going together covid
# new covid wave likely came abroad expert say
# china call tightened response new covid outbreak affect region
# people china complete covid vaccination
# thousand medical student answer gansu call volunteer
# thousand medical student answer gansu call volunteer
# chinese mainland report locally transmitted covid case
# lanzhou supply tcm covid prevention control
# residential community closed management beijing
# china tightens epidemic measure culture tourism industry
# china take swift measure contain new covid infection
# beijing raise one district medium risk level
# china inner mongolia report confirmed covid case
# chinese mainland report locally transmitted covid case
# chinese medical researcher develop hand aid disabled
# gansu hebei tighten anti covid measure
# chinese mainland report locally transmitted covid case
# chinese health authority issue measure shield worker cold
# covid case raise fear winter spread
# china ningxia report new confirmed covid case
# china gansu report new confirmed covid case
# authority scramble find virus link tour group
# china inner mongolia report confirmed covid case
# intelligent health within reach township
# chinese mainland report locally transmitted covid case
# chinese vice premier stress accelerating covid drug research
# beijing report first covid case two month
# inner mongolia report confirmed covid case
# chinese mainland report locally trasmitted covid case
# tourist test positive virus
# china beef capacity building clinical discipline
# thousand volunteer sign help medical research
# china kick seasonal influenza vaccination
# shaanxi report covid confirmed case
# ningxia report locally transmitted confirmed covid case
# chinese mainland report imported covid case local infection
# nation set ensure food security
# covid vaccine administered chinese mainland
# shaanxi record two new coronavirus case
# chinese mainland report imported covid case local infection
# asymptomatic carrier covid reported urumqi
# chinese mainland report new imported covid case
# booster shot rollout begin city heilongjiang
# yunnan offer booster shot fight potential imported case
# chinese mainland report new imported covid case
# covid vaccine administered chinese mainland
# chinese mainland report new imported covid case
# chinese health authority call measure monitor young student eyesight
# chinese vice premier stress covid containment fall winter season
# probe virus origin need collaboration
# shining light medicine china turn
# chinese mainland report new imported covid case
# local government roll booster shot
# local government roll booster shot
# new locally transmitted asymptomatic case yunnan
# chinese mainland report imported covid case
# chinese mainland report imported covid case
# bigger overseas role tcm
# heilongjiang brings latest outbreak control
# putian covid restriction
# expert call increased mental health funding
# chinese mainland report imported covid case local infection
# chinese mainland report imported covid case local infection
# china release medical security plan deepen health reform
# chinese mainland report imported covid case local infection
# booster shot plan drawn
# insurer set sight pet owner
# chronicle outlining mission published
# shanghai credit quick response effective epidemic control
# china chest pain treatment center
# virus contained fujian heilongjiang outbreak critical phase
# pet cat virus euthanized heilongjiang
# heilongjiang report new virus case asymptomatic carrier
# chinese mainland report new locally transmitted covid case
# politicization virus must stop meeting told
# intl forum seek promote greater understanding tcm culture
# thousand vaccine administered mainland
# new virus case reported harbin
# center infectious disease guangdong public bidding
# traditional chinese medicine play important role covid treatment senior expert
# chinese mainland report new locally transmitted covid case
# year plan pledge cut mortality rate
# covid origin investigated worldwide pandemic prevention lancet
# chinese mainland report new locally transmitted covid case
# china written blueprint virus prevention
# sinopharm cross critical threshold vaccine
# digital technology help medical treatment china
# new covid case reported china heilongjiang
# psychiatric service depression lacking paper
# vaccine effective reducing severe illness death say head china cdc
# clinical efficacy proof key tcm progress
# chinese mainland report new locally transmitted covid case
# covid patient discharged hospital china xiamen
# chinese mainland report new locally transmitted covid case
# delta variant discovered harbin outbreak
# foreigner aged get vaccinated guangzhou
# tibet maintains defense covid
# new vaccine protects previously infected
# three province roll covid booster shot
# heilongjiang covid risk rise
# patient enter remission receiving new cancer therapy
# city guangdong approves jab
# avian flu virus show guangdong
# humanitarian spirit saving life
# tackling disease joint task global medical professional
# mass testing continues fujian case reported
# chinese mainland report new locally transmitted covid case
# peking union hospital celebrates year
# measure curb virus spread fujian
# first fujian infection likely happened quarantine
# fujian outbreak sourced school factory
# people china complete covid vaccination
# guangzhou intl health station set open sept
# chinese mainland report new locally transmitted covid case
# number human rabies case continues drop
# chinese scientist detail delta variant transmission chain
# jab rate among older student top
# new plan passed better meet medical need
# fujian widens effort control outbreak
# step mass dog vaccination beat rabies expert
# extra push vaccinate student faculty vaccination rate top
# fujian report new covid case
# artificial hip knee set become cheaper
# shanghai offer jab foreign minor
# highlight high quality healthcare
# nucleic acid testing guideline revised delta variant
# month old donor save teen life
# jiangsu clear locally transmitted covid case
# china xiamen start citywide covid testing
# chinese mainland report new locally transmitted covid case
# fujian covid outbreak contained oct
# virus hit county fujian conduct mass testing
# china rank ninth global fatigue study
# chinese mainland report new locally transmitted covid case
# putian report case delta variant likely
# billion covid vaccine administered china
# east china town classified covid high risk
# chinese mainland report new locally transmitted covid case
# sinovac launch clinical trial covid vaccine child teenager south africa
# east china fujian report locally transmitted covid case
# school taiwan child join city jab drive
# new system cut medicine price hainan province
# booster shot covid variant
# research aim prepare virus variant
# china vaccine effective covid variant senior official
# covid vaccine research progress clinical trial stage
# nation population vaccinated
# testing kit coronavirus flu virus
# medical leader share thought high quality development
# sinopharm get test drug covid
# close contact asymptomatic virus carrier guangzhou test negative
# close contact guangzhou case given clear
# chinese mainland report new locally transmitted covid case
# china strengthens regulation medicine use
# covid vaccine administered china
# chinese mainland report new locally transmitted covid case
# report point improved health fitness youth
# timeline china transparency fight covid
# better overall health fitness among chinese student
# doctor book take new look hypertension
# younger people open plastic surgery
# problem show ugly face beauty industry
# acupuncture treat post covid condition overseas
# anthrax case prompt call improve awareness
# china developed robot begin clinical trial gynecological surgery
# research link covid cold chain urged
# senior health official origin tracing report
# shanghai expands vaccination drive youngster
# chinese mainland report new locally transmitted covid case
# vaccine given wuhan
# new chinese vaccine percent effective delta variant
# plan aim eliminate cervical cancer
# first sinovac vaccine sent algeria
# nation back deeper study covid origin shifting blame
# china zhengzhou clear covid medium high risk area
# embassy report virus credible
# vaccine arm top across country
# china reluctant share data pandemic
# high tech show take aim covid
# booster recommended select group
# ministry clarifies epidemic prevention rule school
# covid vaccine given mainland
# video new series expose lab leak lie
# shanghai new case relates airport cluster
# official held liable covid lapse
# china yunnan report locally transmitted confirmed covid case
# virus test carried mountain helicopter
# chinese kit test novel coronavirus flu
# booster shot health agenda
# northeastern city check vaccination proof public place
# negative covid test required returning college faculty student
# new local case covid reported
# china inactivated vaccine effective delta variant study
# shanghai airport worker imported infection likely people environment
# chinese mainland report new covid case imported
# zhengzhou clear area high covid risk
# new covid case found shanghai
# two infection found shanghai
# legislation better protect doctor
# shanghai authority provide update latest covid case
# mainland discus quarantine free travel arrangement
# lam say govt fully prepared legco election
# medium tycoon jimmy lai jailed month
# macao mainland young life progress
# jimmy lai sentenced month jail
# world nancy kwan
# shade
# liaison office central gov macao sar welcome local legislation instituting national security adviser
# macao enhances cooperation jiangsu province
# macao sar gov completes legislation instituting national security adviser
# singapore fintech complementary
# grad find best option anhui
# jimmy lai two others convicted unauthorized assembly
# student pursues culture chinese mainland
# commissioner democracy summit deception essence
# new electoral system expected better serve resident interest
# astronaut orbit give space lesson macao student
# democracy unique aim improving livelihood
# xia revamped electoral system open new page democracy
# entrepreneur guangzhou stretch success
# mainland olympic athlete visit spark sport fever hong kong
# resident responsibility respect safeguard constitutional order lam
# mainland olympic star inspiration student
# hong kong report new imported covid case
# olympian visit expected ignite sport passion
# focus new stage regional international cooperation
# tokyo olympic medalist visit hong kong
# homing economy
# central gov decides institute adviser committee safeguarding national security macao sar
# platform path social security benefit mainland
# fok blessed homeland partner guide
# omicron variant isolated hku team asia first
# memory lane visit mainland olympic delegation
# new opportunity highlighted
# bid farewell cage home
# well poised become global arbitration hub
# court order arrest accused calling legco poll boycott
# china establish arbitration center african panel
# detained macao police gambling
# resident mainland vote checkpoint legco poll
# tightens entry rule omicron variant
# legco hopeful livestreamed open debate hong kong future
# lam look forward mainland olympian visit
# business leader encouraged seize gba opportunity
# launch health code system dec
# carrie lam highlight need national education online talk teacher
# new documentary look macao food culture
# war epic must see say moviegoer
# man sentenced month inciting secession money laundering
# quarantine free travel mainland focus shenzhen meeting
# voting plan resident mainland released
# mainland expert visit huge step toward quarantine free travel
# hksar govt approves lowering age limit sinovac covid vaccine
# validly nominated legco election
# legco poll vetting panel clear one hopeful
# university macau launch first dpa program
# hksar gov strongly opposes china economic security review commission report
# one country two system secures bright future sars
# mainland social security system welcome resident
# visa issuance overseas reporter autonomy sar govt
# sars youngster see promising bay area
# nearly people hong kong get booster shot covid vaccine
# support multilateralism overcoming global crisis carrie lam
# nomination form hksar legco election received deadline
# cpc role hong kong widely praised
# hong kong expects gdp grow amid firm recovery
# insurance extends macao people guangzhou
# probiotic producer make grade science park
# lead fintech race leveraging strategic asset
# euro denominated bond hot property
# hong kong see decrease poor population hksar govt policy intervention report
# give talk basic law nov
# mull voting plan resident mainland
# participates actively import expo
# resident confident legco diversity
# mainland higher education institution admit student
# forum highlight new opportunity greater bay area
# commissioner office chinese foreign ministry urge foreign correspondent club stop vilifying rule law hong kong
# mainland hong kong working toward resumption quarantine free travel
# bag six nation top science award
# activist pleads guilty secession money laundering
# professor look city future science
# hong kong unveils new measure boost fintech
# hong kong must utilize extensive network capitalize gba opportunity carrie lam
# mous signed boost maritime development
# financial sector embrace new opportunity
# resident visit exhibition chinese architecture
# engineering expertise key industry development gba
# macao jobless rate july sept rise
# lecturer talk architecture
# dab announces candidate legco poll
# undying spirit
# revolutionizing landscape economy
# macao merchandise trade continues rise september
# hong kong legislature resume normal enactment national security law legco president
# hksar student awe nation construction prowess
# hksar child hospital make life better little patient
# cuhk lecture highlight architecture cultural role
# medical facility reflect mainland engineering efficiency
# two hospital show benefit cooperation
# disneyland eye gba recovery
# chief engineer share nation technology innovation hkust
# world first stamp penny black display hong kong
# desalination plant slated operation
# expert discus construction anti pandemic hospital project polyu
# mainland delegation tour boost sense national pride
# spirit time shine upon
# spectacular architectural exhibition impress pupil teacher
# architecture exhibition solidifies link country
# exhibition nation architectural achievement open
# key project connect hong kong mainland
# cultivating upstanding citizen must start early
# opportunity abound construction sector
# hong kong touchstone sincerity china daily editorial
# serving hong kong honour duty loyalty
# hksar government strongly reject condemns interference foreign politician
# commissioner office chinese foreign ministry blast western politician remark democracy hong kong
# graphic making progress intl ranking rule law
# graphic commissioner office urge washington stop interfering affair
# graphic labor market improves economic recovery take hold
# forum explores nansha new role guangdong tie
# hksar chief executive election held march
# butterfly soar high love light wing
# scale new height
# rest assured
# sovereign bond issued mof hong kong oversubscribed time
# oath hksar district council member announced invalid
# state council appoints new head custom hksar
# macao court hear fewer case past judicial year
# enhance status intl shipping hub nat support official
# hong kong strong new power fight wildlife crime
# earmarked safeguard national security hong kong
# hong kong eager sporting success
# five cuhk student get month jail riot
# hong kong business environment remains vibrant official
# carrie lam leaf hospital minor elbow fracture fall
# macao bank launch wealth management connect related service
# young people hong kong better grasp development opportunity mainland finance chief
# member legislative assembly macao sworn
# travel permit renewal convenient hong kong macao resident chinese mainland
# new public school teacher required basic law test
# magnet global investor
# vocational education removing stigma
# resetting work skill equation
# campus far near
# shenzhen bond debut seen milestone
# lam visit guangdong deepen tie
# welcome liaison office outreach
# chief secretary administration hksar gov vow actively implement policy address
# chau supporting smes vital grassroots population
# chan policy address boost youth confidence future
# commissioner chinese foreign ministry hksar hold group briefing honorary consul
# hong kong welcome oecd announcement beps implementation plan
# hong kong invest climate change mitigation next year
# startup find favorable opportunity qianhai
# business role model world
# macao issue signal tropical storm lionrock
# pic boost patriotic sentiment hong kong
# outreach activity boost tackling deep seated problem
# chui promote sustainable fishery development
# kowloon chamber govt uphold people centered spirit
# amended national flag emblem bill come effect hksar
# liaison office central gov support hksar gov seizing opportunity bolstering economy
# central gov spokesperson lauds hksar chief executive policy address
# nomination hksar legco election start oct
# oath hksar district council member announced invalid
# chan dialogue official propel tcm development
# lam confident plan implementation
# hong kong custom detects largest smuggling case record
# hong kong rank globally fdi inflow carrie lam
# carrie lam unveils new measure reinforce financial strength
# unveils major housing plan policy address
# hong kong back right track one country two system carrie lam
# develop new metropolis northern area people
# set grasp new opportunity
# policy address grasp new opportunity new era
# central govt official outreach activity receive welcome
# national security law safeguarded business environment hong kong
# hksar fully restores security normalcy chief administration secretary
# youngster compete putonghua speech contest
# future youth lie city integration national development
# hong kong next green financial center world
# hong kong win today win tomorrow
# vibrant national day festivity
# macao sar chief executive pledge progressively implement policy depth zone hengqin
# macao september gaming revenue surge time year year
# national day resident high spirit
# hong kong truly right track one country two system carrie lam
# resident celebrate national day decorated bus
# chuang bright future awaits fintech payment industry
# ...
# chinese official rebuke abusing democracy
# china lao railway begin service
# china issue white paper democracy
# upholding constitution protect democracy
# boeing max could back sky month
# jiangsu award individual stopping domestic violence
# extends congratulation anniversary overseas broadcasting service
# luosifen sale volume set record
# drone capture image unique miao village
# china top court clarify biodiversity protection law
# nuclear heating project commissioned south china
# search rescue operation save sailor
# dawn redwood tree changguangxi national wetland park turn reddish brown
# measure aim promote coal transport road
# rest mandated food courier
# spp recommends harsher punishment wage default
# court boost legal service disabled
# tibetan livelihood improving regional party congress told
# creating rule law chinese characteristic
# chinese fugitive accused money laundering extradited serbia
# broader international audience people disability china
# conference promotes understanding china
# harbin reward people initiative covid
# tibet review five year progress
# guizhou native expands noodle business overseas
# soccer skill help student score pitch
# construction cross sea high speed railway bridge fujian complete
# china issue digital driver license nationwide
# killed injured east china coach truck collision
# china top court highlight penalty evasion obstruction law enforcement
# universal beijing resort plan expansion
# service corner improving life outdoor worker
# profit bubble hot spring nagchu
# love security essence care
# good start still long way
# tongzhou cure big city disease
# hospice give child dignity final day
# grass planting boost village income
# gansu ruin shed light ancient civilization
# historical resolution show party confidence
# canada goose draw ire refund policy
# yunnan make stride ending disease
# effort urged curb hiv aid
# govt vow clear arrears owed smes
# former senior provincial official probe
# temple jiangsu offer stunning view tourist
# doctor safeguard village southwest china year
# alumnus donates record wuhan university
# comprehensive energy station open guangzhou come
# tibet make progress woman child
# renovation project year surpass goal
# expert note achievement burgeoning sector say challenge remain
# qingdao brewer help resident gansu city improve livelihood
# barber trim way top profession
# old cold noodle dish becomes hot new favorite
# beijing gear green sustainable winter game
# former political adviser pleads guilty graft
# ride hailing driver right get protection
# city help shield nation outbreak
# official elderly need vaccine booster
# magnitude quake hit tibet cenc preliminary report
# former top adviser pleads guilty graft
# drone reveals unusual earthen dwelling anhui
# tianjin parent get longer child care leave
# shanghai broadens hukou eligibility
# new sco judicial center work exchange legal improvement
# chinese mainland report locally transmitted covid case
# painting new growth landscape
# restaurant owner inspires charity
# spp target illegal casino
# detained macao police gambling
# hunter take aim wild boar number soar
# tech keep bullet train running xinjiang desert
# shanghai quick response minimizes spread virus
# new case found manzhouli
# medium center set side event olympics
# beijing report year year jump new hiv aid case
# video brings back tender memory mother
# tibet sends nearly bln kwh electricity clean energy
# cliffside bookstore boost village development
# shanghai hospital resume normal operation
# inner mongolia record one new locally transmitted confirmed case
# livestreaming becoming popular career choice
# new measure hasten shipment emergency supply heihe resident
# older job seeker run employment hurdle
# green truck used coal transportation
# shanghai cafe warm place community heart
# beijing host intl conference science literacy
# prisoner escaped jilin captured
# beijing standardize foreign language sign public place
# beijing start commercial trial self driving vehicle
# beijing subcenter aim high
# beijing elderly population hit million
# fudan confers award top management talent
# world oldest tea residue discovered
# china release development guideline beijing sub center
# china procuratorate order arrest disciplinary inspector tobacco monopoly
# xinjiang invests yuan road construction
# beijing sub city center projected completed
# beijing clear covid risk area
# measure taken improve elderly care
# shanghai parent get longer child care leave
# expect compromise taiwan question
# online job fair lure global talent beijing
# chinese police smash huge cross border gambling gang
# crackdown express delivery contraband
# chinese mainland report locally transmitted covid case
# positive role internet medium hailed forum
# shanghai hangzhou report new covid case
# new shanghai parent get leave extension
# single child zhejiang given day vacation see parent
# chinese woman federation issue evidence guide domestic violence
# disabled man return favor bitter cold warms netizens
# work late jewish photog donated museum
# chinese mainland report two locally transmitted covid case
# government action plan promotes breastfeeding
# beijing outline plan regulate residential rental
# yunnan people help border control
# tibetan opera take center stage
# china roll measure address population aging boost well elderly
# printed farmhouse erected rural hebei
# code help senior find way back home
# green economic development propels suzhou wujiang district
# new specie thrive guangdong oasis desert belt
# china france offshore wind farm start operation jiangsu
# migratory bird arrive tianjin
# bln covid vaccine administered chinese mainland
# chose soldier film academy graduate
# mayor promote global exchange hangzhou sister city conference
# olympic village preparation weekend test
# scholar call protection afghan cultural relic
# chinese mainland report four locally transmitted covid case
# scientist learn party history
# demographer unties china falling marriage conundrum
# disabled man find success raising chicken
# tianjin reveals world zero carbon terminal
# pilot area facilitate coastal shipping
# winter paralympics target lasting legacy disabled
# charity donor stay anonymous year
# coal region ordos set pace green switch
# public role advising legislation grows
# neonatal critical care center open tibet
# wujiang ecological progress eye pakistani
# china promote recovery civil aviation industry
# genetic resource rare livestock specie discovered survey
# lie cannot shake xinjiang stability spokesperson
# intl freight line open new horizon jilin
# chinese mainland report locally transmitted covid case
# teacher visit home instruct disabled student
# tea tourism key county drive boost income
# internet livestreaming host fined tax evasion
# winter game shift focus temporary facility
# subtitle website founder jailed film piracy
# dormitory partial collapse kill east china
# geological worker found dead
# eye star teenager clinch top prize photo
# greater effort urged encourage birth
# child enjoy snow jilin
# founder pirated video website fined jailed
# missing geological worker yunnan confirmed dead
# killed injured blast china community
# symphony concert celebrates china rok tie
# two livestreaming host fined tax evasion
# thai festival light guangzhou
# hunan man care forest year
# china europe freight train eclipse previous record
# shanghai cafe warm place community heart
# railway station expansion boost transport capacity
# hengnan hybrid double crop rice set national record
# qinghai herder turn yak milk cash cow
# gen zer lauded caring father
# unexpected leopard population found tibet
# alert issued cold air hit nation
# trial completed passenger service information system china lao railway lao section
# pct young chinese intend side job survey
# video autumn qingdao
# city light blue mark world child day
# image life pandemic ruili
# virus outbreak waning say national health body
# china issue five year plan protection utilization major historical site
# wujiang harmonious balance nature preservation economic progress
# china issue procedure fostering rural legally savvy talent
# china renews blue alert cold wave
# chinese mainland report three locally transmitted covid case
# capital set community association
# tibet college buddhism mark anniversary
# guangzhou power grid heals
# eliminating wild boar tricky problem
# six sentenced leopard escape hangzhou
# search continues geological worker
# rail welding completed desert loop xinjiang
# expat discover vibrant greenery ecological progress wujiang
# man get year violating epidemic control prevention rule
# ancient wisdom find new fan qufu confucius museum
# tibetan emergency bureau receives good performance award
# tireless rescue official honored hero model
# strict punishment urged prevent bullying
# cold wave set hit tricky like fox
# allergy patient welcome effort pull plant
# china firmly opposes smear religious freedom spokesperson
# migratory gull grace wetland yinchuan
# beijing want volunteer association
# evidence collection minor sexual assault case standardized across shanghai district
# retired professor make physic fun
# harbin former official face life corruption abuse power
# cpc unites people respond covid eradicate poverty pakistani analyst
# rediscovering root
# border villager team take virus
# policy digest
# short distance tour becoming popular option outbreak persist
# policy aim help tourist agency
# guangdong launch bay area qualification service
# caac seek feedback boeing jet
# chinese police arrest involved telecom fraud
# popular song put city mohe spotlight
# legoland shanghai resort construction
# building china impressive high speed rail
# cat receives care owner quarantine
# ruili waif accommodation fee people quarantine
# magnitude quake hit water east china coast
# astronaut flow space tai chi
# effect home literacy environment chinese preschooler differs age study
# tibetan teacher take gratitude new height
# cyberspace watchdog continues cleaning internet
# beijing heightens covid control
# student hospitalized falling school building
# charity raise child art education
# government put safety top agenda
# demand cybersecurity qualified expert rise
# cybersecurity guru bolster online integrity
# polyculture breathes new life shoreline
# ministry say fugitive repatriation show determination fight corruption
# fugitive repatriation show determination fight corruption
# woman rescue video win praise online
# new draft regulation aim improve data security
# new rail ticket serve beijing tianjin commuter
# gansu corn seed prepared spring planting
# memorial service father hybrid rice
# guizhou student realize musical dream rock band
# life getting sweeter bee farmer
# delivery service expands remote region
# nation tackle imbalance rule law advance
# cooperation urged fight relic trafficking
# ship blocked suez canal repaired china
# scientist establish research center northeast asia biodiversity conservation
# china tightens covid prevention measure border port
# cross sea high speed railway bridge completes joining
# chinese mainland report locally transmitted covid case
# online vet care service spring china
# technique famed lacquer art protected fujian
# insurance extends macao people guangzhou
# china release updated medicare reimbursement list
# swan take brief rest inner mongolia
# beijing adding new subway line year end
# china civil aviation achieves safe flight month row
# official laud spirit late agronomist yuan longping
# chinese mainland report locally transmitted covid case
# new covid case beijing linked oil company conference
# city take lead heating clean energy
# internet buzzword lying flat spark debate
# china breed endangered primate captivity
# relief full swing tackle record blizzard
# chinese police solve online counterfeiting case
# chinese mainland report locally transmitted covid case
# lhasa group help preserve tibetan art form
# nation aim narrow wealth gap
# capital airport boost olympic precaution
# nation strengthens grassroots democracy
# ['volunteer work see tree planted china ', 'heavy snow human take food antelope ', 'key meeting stress proper understanding china carbon neutrality goal ', 'china release rare fish yangtze river ', 'china make notable progress water soil conservation ', 'giant panda bounce back thanks reforestation ', 'ecological corridor help expand giant panda habitat ', 'migratory bird seen yinchuan ', 'beijing look forward end heavily polluted day ', 'wetland protection reaps rich reward ', 'team assist bird search food ', 'rare bird spotted china nature reserve ', 'chinese researcher discover new wild orchid specie ', 'country vow water cooperation ', 'migratory flamingo winter bird shanxi ', 'action plan improve rural living condition ', 'china top court clarify biodiversity protection law ', 'inspection focus high emission project ', 'beijing see increasing migratory bird winter ', 'inspection uncovers soe violation ', 'complex cure key curbing desertification ', 'beijing expects avian guest winter ', 'scientist urge better monitoring glacier ', 'benefit flowing plan river basin protection ', 'generation effort protect china second largest freshwater lake ', 'king monkey make furry friend forest ', 'top court urge judicial support river basin protection ', 'nation eye action plan methane emission ', 'china severely punish environmental law violation key river basin ', 'firm pay yuan damage nature ', 'court ordered crack harder river polluter illegal sand miner ', 'china vow soon set working group climate action ', 'ministry lauds progress securing compensation environmental damage ', 'china coastal city combat invasive plant ', 'coal rich ordos setting green pace ', 'bri project given green emphasis ', 'wild bird flock ningxia yinhe bay ', 'new legislation protect wintering bird major freshwater lake ', 'china leading way carbon capture technology report ', 'supervision private investment environmental project stepped ', 'livestock plant resource survey track ', 'trip suzhou finding peace healing power nature ', 'nearly rare fish fry released yangtze river tributary ', 'rule cut groundwater exploitation ', 'innovation crucial achieving carbon goal ', 'china aim safeguard groundwater new rule ', 'expert china play important role tackling climate change ', 'snow leopard roam hydropower station ', 'forum brings energy expert green transition ', 'china installed capacity renewable power top ', 'shoreline restored protect ecology ', 'eliminating wild boar tricky problem ', 'eco civilization flourish vision ', 'china responsible apec forest increase ', 'nation facilitate green growth ', 'community conservation lead way yunnan noah ark ', 'gansu new energy help power province ', 'private sector urged contribute green drive ', 'hive activity aid survival ', 'nation seek counter effect rising sea level ', 'high hope greener supply chain ', 'efficient use energy key carbon goal ', 'shopping spree new battlefield reduce carbon ', 'china raise environmental awareness among young student ', 'china matching green word action ', 'nation need improve energy use efficiency phase coal ', 'single day shopping gala feature green consumption ', 'china civil aviation achieves progress reducing emission ', 'endangered fish released xinjiang major lake ', 'beijing washington sign joint climate declaration ', 'circular aim percent cut ', 'nov online shopping spree get greener ', 'international wetland meeting scheduled wuhan ', 'chilly winter due global warming expert ', 'help nation drive toward climate goal ', 'expert criticize carbon price plan ', 'climate resilient investment pay ', 'china host cop meeting convention wetland ', 'high speed rail cut greenhouse gas emission ', 'cold snap hit southern northeastern area ', 'report recommends heavy investment climate resistant infrastructure ', 'many migratory bird making stop ningxia ', 'youth take lead climate summit ', 'ruicheng fortune rise sun ', 'china issue circular control pollution ', 'first snow season ...

# %%
tokenizer=Tokenizer()  #创建一个Tokenizer对象
#fit_on_texts函数可以将输入的文本中的每个词编号，编号是根据词频的，词频越大，编号越小
tokenizer.fit_on_texts(X)
vocab=tokenizer.word_index #得到每个词的编号

print(vocab)

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1)

x_train_word_ids = tokenizer.texts_to_sequences(x_train)
x_test_word_ids = tokenizer.texts_to_sequences(x_test)
#序列模式
# 每条样本长度不唯一，将每条样本的长度设置一个固定值
x_train_padded_seqs = pad_sequences(x_train_word_ids,maxlen=20) #将超过固定值的部分截掉，不足的在最前面用0填充
x_test_padded_seqs = pad_sequences(x_test_word_ids, maxlen=20)
print(x_train_padded_seqs)
# print(x_train_word_ids)
# Out:
# {'china': 1, 'chinese': 2, 'new': 3, 'covid': 4, 'case': 5, 'military': 6, 'report': 7, 'mainland': 8, 'national': 9, 'hong': 10, 'kong': 11, 'pla': 12, 'space': 13, 'nation': 14, 'plan': 15, 'macao': 16, 'official': 17, 'development': 18, 'beijing': 19, 'launch': 20, 'paper': 21, 'locally': 22, 'transmitted': 23, 'cpc': 24, 'help': 25, 'high': 26, 'set': 27, 'issue': 28, 'white': 29, 'year': 30, 'key': 31, 'top': 32, 'green': 33, 'first': 34, 'satellite': 35, 'cooperation': 36, 'people': 37, 'law': 38, 'student': 39, 'shanghai': 40, 'system': 41, 'virus': 42, 'election': 43, 'astronaut': 44, 'global': 45, 'say': 46, 'boost': 47, 'area': 48, 'mission': 49, 'carbon': 50, 'biodiversity': 51, 'expert': 52, 'vaccine': 53, 'world': 54, 'democracy': 55, 'stress': 56, 'measure': 57, 'ministry': 58, 'security': 59, 'climate': 60, 'forum': 61, 'policy': 62, 'open': 63, 'premier': 64, 'day': 65, 'taiwan': 66, 'make': 67, 'city': 68, 'station': 69, 'air': 70, 'effort': 71, 'sea': 72, 'tech': 73, 'two': 74, 'test': 75, 'hold': 76, 'take': 77, 'force': 78, 'get': 79, 'show': 80, 'senior': 81, 'border': 82, 'service': 83, 'defense': 84, 'hksar': 85, 'release': 86, 'country': 87, 'urged': 88, 'office': 89, 'party': 90, 'meeting': 91, 'action': 92, 'role': 93, 'control': 94, 'central': 95, 'tibet': 96, 'medical': 97, 'shenzhou': 98, 'progress': 99, 'aim': 100, 'guideline': 101, 'govt': 102, 'child': 103, 'health': 104, 'exercise': 105, 'conservation': 106, 'protection': 107, 'urge': 108, 'group': 109, 'call': 110, 'record': 111, 'committee': 112, 'change': 113, 'energy': 114, 'opportunity': 115, 'river': 116, 'improve': 117, 'technology': 118, 'vice': 119, 'anti': 120, 'resident': 121, 'start': 122, 'lam': 123, 'political': 124, 'ship': 125, 'navy': 126, 'goal': 127, 'vow': 128, 'court': 129, 'project': 130, 'scientist': 131, 'protect': 132, 'aid': 133, 'need': 134, 'study': 135, 'mongolia': 136, 'chief': 137, 'research': 138, 'science': 139, 'mar': 140, 'work': 141, 'better': 142, 'support': 143, 'trial': 144, 'inner': 145, 'life': 146, 'step': 147, 'industry': 148, 'one': 149, 'foreign': 150, 'regulation': 151, 'game': 152, 'water': 153, 'find': 154, 'session': 155, 'operation': 156, 'carrier': 157, 'peacekeeping': 158, 'bird': 159, 'team': 160, 'power': 161, 'center': 162, 'five': 163, 'video': 164, 'win': 165, 'environment': 166, 'begin': 167, 'guangzhou': 168, 'local': 169, 'variant': 170, 'testing': 171, 'booster': 172, 'imported': 173, 'visit': 174, 'right': 175, 'see': 176, 'focus': 177, 'rule': 178, 'innovation': 179, 'growth': 180, 'yunnan': 181, 'online': 182, 'hit': 183, 'south': 184, 'month': 185, 'zone': 186, 'outbreak': 187, 'shot': 188, 'sar': 189, 'talk': 190, 'strait': 191, 'back': 192, 'winter': 193, 'level': 194, 'xinjiang': 195, 'joint': 196, 'honor': 197, 'found': 198, 'meet': 199, 'police': 200, 'success': 201, 'state': 202, 'intl': 203, 'army': 204, 'ecological': 205, 'nature': 206, 'researcher': 207, 'inspection': 208, 'bay': 209, 'supply': 210, 'speed': 211, 'region': 212, 'offer': 213, 'building': 214, 'highlight': 215, 'quality': 216, 'unveils': 217, 'former': 218, 'administered': 219, 'strengthen': 220, 'hospital': 221, 'public': 222, 'develop': 223, 'guangdong': 224, 'gov': 225, 'rocket': 226, 'crew': 227, 'minister': 228, 'rural': 229, 'emission': 230, 'benefit': 231, 'wuhan': 232, 'cop': 233, 'rise': 234, 'park': 235, 'observation': 236, 'future': 237, 'keep': 238, 'council': 239, 'authority': 240, 'home': 241, 'confirmed': 242, 'drug': 243, 'vaccination': 244, 'conduct': 245, 'fujian': 246, 'business': 247, 'education': 248, 'rover': 249, 'aircraft': 250, 'spokesman': 251, 'advisor': 252, 'human': 253, 'food': 254, 'way': 255, 'released': 256, 'eco': 257, 'gansu': 258, 'drive': 259, 'young': 260, 'international': 261, 'youth': 262, 'pollution': 263, 'full': 264, 'promote': 265, 'advance': 266, 'conference': 267, 'return': 268, 'travel': 269, 'railway': 270, 'legislative': 271, 'omicron': 272, 'greater': 273, ' ...
# [[   0    0    0 ...  622  615  855]
#  [   0    0    0 ...   47  158   49]
#  [   0    0    0 ... 1853 1854   38]
#  ...
#  [   0    0    0 ...  162   63  224]
#  [   0    0    0 ...  378   50  789]
#  [   0    0    0 ...  226 1691   49]]

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
# print(y_train)
y_test = to_categorical(y_test)
# print(x_train)
print(x_train_padded_seqs)
# print(x_test_padded_seqs.shape)
# Out:
# [[   0    0    0 ...  622  615  855]
#  [   0    0    0 ...   47  158   49]
#  [   0    0    0 ... 1853 1854   38]
#  ...
#  [   0    0    0 ...  162   63  224]
#  [   0    0    0 ...  378   50  789]
#  [   0    0    0 ...  226 1691   49]]

# %%
#构建CNN分类模型(LeNet-5)
#模型结构：嵌入-卷积池化*2-dropout-BN-全连接-dropout-全连接
model = Sequential()
model.add(Embedding(len(vocab) + 1, 300, input_length=20)) #使用Embeeding层将每个词编码转换为词向量
model.add(Conv1D(256, 5, padding='same'))
model.add(MaxPool1D(3, 3, padding='same'))
model.add(Conv1D(128, 5, padding='same'))
model.add(MaxPool1D(3, 3, padding='same'))
model.add(Conv1D(64, 3, padding='same'))
model.add(Flatten())
model.add(Dropout(0.1))
model.add(BatchNormalization())  # (批)规范化层
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(7, activation='softmax'))

from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=2)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train_padded_seqs, y_train,
                    epochs=10, batch_size=64, 
                    validation_data = (x_test_padded_seqs, y_test),
                    callbacks=[early_stopping])
# Out:
# Epoch 1/10
# 38/38 [==============================] - 8s 173ms/step - loss: 1.6980 - accuracy: 0.3567 - val_loss: 1.8108 - val_accuracy: 0.5000
# Epoch 2/10
# 38/38 [==============================] - 5s 133ms/step - loss: 0.4986 - accuracy: 0.8521 - val_loss: 1.6763 - val_accuracy: 0.5827
# Epoch 3/10
# 38/38 [==============================] - 4s 112ms/step - loss: 0.2358 - accuracy: 0.9478 - val_loss: 1.5994 - val_accuracy: 0.4586
# Epoch 4/10
# 38/38 [==============================] - 4s 113ms/step - loss: 0.1563 - accuracy: 0.9645 - val_loss: 1.4601 - val_accuracy: 0.6429
# Epoch 5/10
# 38/38 [==============================] - 4s 114ms/step - loss: 0.1212 - accuracy: 0.9641 - val_loss: 1.3815 - val_accuracy: 0.6880
# Epoch 6/10
# 38/38 [==============================] - 4s 115ms/step - loss: 0.1074 - accuracy: 0.9678 - val_loss: 1.2692 - val_accuracy: 0.6880
# Epoch 7/10
# 38/38 [==============================] - 4s 115ms/step - loss: 0.0981 - accuracy: 0.9628 - val_loss: 1.1833 - val_accuracy: 0.6729
# Epoch 8/10
# 38/38 [==============================] - 4s 111ms/step - loss: 0.0798 - accuracy: 0.9657 - val_loss: 1.0696 - val_accuracy: 0.7143
# Epoch 9/10
# 31/38 [=======================>......] - ETA: 0s - loss: 0.0759 - accuracy: 0.9667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-4ea8b5a89099> in <module>()
#      24                     epochs=10, batch_size=64,
#      25                     validation_data = (x_test_padded_seqs, y_test),
# ---> 26                     callbacks=[early_stopping])
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
import sklearn
import numpy as np
import pandas as pd
import math
import jieba
import pickle
import time
from collections import Counter

class RNNTextClassifier():
    def __init__(self,vocab_size, n_out, embedding_size=128, cell_size=128,
                 grad_clip=5.0,sess=tf.Session()):
        self.vocab_size = vocab_size
        self.embedding_size = embedding_size
        self.cell_size = cell_size
        self.grad_clip = grad_clip
        self.n_out = n_out
        self.sess = sess
        self._pointer = None
        self.buildgraph()

    def buildgraph(self):
        self.add_input_layer()
        self.add_wordembedding_layer()
        self.add_dynamic_rnn()
        self.add_output_layer()
        self.add_optimizer()

    def add_input_layer(self,):
        self.X = tf.placeholder(tf.int32, [None, None])
        self.Y = tf.placeholder(tf.int64, [None])
        self.X_seq_len = tf.placeholder(tf.int32, [None])
        self.keep_prob = tf.placeholder(tf.float32)
        self.lr = tf.placeholder(tf.float32)
        self._pointer = self.X

    def add_wordembedding_layer(self):
        embedding = tf.get_variable("encoder",
                                    [self.vocab_size,self.embedding_size],
                                    dtype=tf.float32,
                                    initializer=tf.random_uniform_initializer(-1.0,1.0))
        embedded = tf.nn.embedding_lookup(embedding, self._pointer)
        # self._pointer = tf.nn.dropout(embedded, keep_prob=self.keep_prob)
        self._pointer = embedded

    def lstm_cell(self):
        lstm_cell = tf.nn.rnn_cell.LSTMCell(num_units=self.cell_size,initializer=tf.orthogonal_initializer())
        return tf.nn.rnn_cell.DropoutWrapper(lstm_cell, output_keep_prob= self.keep_prob)

    def add_dynamic_rnn(self):
        self.outputs, self.last_state = tf.nn.dynamic_rnn(
            cell=self.lstm_cell(),
            inputs=self._pointer,
            sequence_length=self.X_seq_len,
            dtype=tf.float32
        )
    def add_output_layer(self):
        self.logits = tf.layers.dense(self.last_state.h, self.n_out)

    def add_optimizer(self):
        self.loss = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(
                logits=self.logits, labels=self.Y
            )
        )
        self.acc = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(self.logits, axis=1),self.Y),dtype=tf.float32))
        #gradient clipping
        params = tf.trainable_variables()
        gradients = tf.gradients(ys=self.loss, xs=params)
        clipped_gradients, _ = tf.clip_by_global_norm(t_list=gradients, clip_norm=self.grad_clip)
        self.train_op = tf.train.AdamOptimizer(self.lr).apply_gradients(zip(clipped_gradients, params))

    def fit(self, X, Y, val_data=None, n_epoch=10, batch_size=128, exp_decay=True,
            isshuffle=True, keep_prob=0.5):
        if val_data is None:
            print("Train %d samples" % len(X))
        else:
            print("Train %d samples | Test %d samples" % (len(X), len(val_data[0])))
        log = {'loss':[], 'acc':[], 'val_loss':[], 'val_acc':[]}
        global_step = 0
        self.sess.run(tf.global_variables_initializer())
        saver = tf.train.Saver()
        for epoch in range(n_epoch):
            if isshuffle:
                X, Y = sklearn.utils.shuffle(X,Y)
            for local_step, ((X_batch, X_batch_lens), Y_batch) in enumerate(
                    zip(self.next_batch(X, batch_size), self.gen_batch(Y, batch_size))):
                lr = self.decrease_lr(exp_decay,global_step, n_epoch, len(X), batch_size)
                _, loss, acc = self.sess.run([self.train_op, self.loss, self.acc],
                                             feed_dict={self.X:X_batch,
                                                        self.Y:Y_batch,
                                                        self.X_seq_len:X_batch_lens,
                                                        self.lr:lr,
                                                        self.keep_prob:keep_prob})
                global_step += 1
                if local_step % 50 == 0:
                    print("Epoch %d | Step %d%d | Train loss: %.4f | Train acc: %.4f | lr: %.4f" % (
                        epoch+1, local_step, int(len(X)/batch_size), loss, acc, lr
                    ))
                log['loss'].append(loss)
                log['acc'].append(acc)

            if val_data is not None:
                val_loss_list, val_acc_list = [],[]
                for (X_test_batch,X_test_batch_lens), Y_test_batch in zip(self.next_batch(val_data[0], batch_size),
                                                                          self.gen_batch(val_data[1],batch_size)):
                    v_loss, v_acc = self.sess.run([self.loss, self.acc],feed_dict={
                        self.X: X_test_batch, self.Y: Y_test_batch,
                        self.X_seq_len:X_test_batch_lens, self.keep_prob:1.0
                    })
                    val_loss_list.append(v_loss)
                    val_acc_list.append(v_acc)
                val_loss, val_acc = self.list_avg(val_loss_list), self.list_avg(val_acc_list)
                log['val_loss'].append(val_loss)
                log['val_acc'].append(val_acc)
                print("val_data loss: %.4f | val_data acc: %.4f" % (val_loss, val_acc))
        saver.save(self.sess,"c:/users/ll/desktop/model/model.ckpt")
        return log

    def predict(self, X_test, batch_size=128):
        batch_pred_list = []
        for (X_test_batch, X_test_batch_lens) in self.next_batch(X_test, batch_size):
            batch_pred = self.sess.run(self.logits,feed_dict={
                self.X: X_test_batch,
                self.X_seq_len: X_test_batch_lens,
                self.keep_prob: 1.0
            })
            batch_pred_list.append(batch_pred)
        return np.argmax(np.vstack(batch_pred_list), 1)

    def pad_sentence_batch(self, sentence_batch, pad_int=0):
        max_lens = max([len(sentence) for sentence in sentence_batch])
        padded_seqs = []
        seq_lens = []
        for sentence in sentence_batch:
            padded_seqs.append(sentence + [pad_int] * (max_lens-len(sentence)))
            seq_lens.append(len(sentence))

        return padded_seqs, seq_lens

    def next_batch(self, arr, batch_size):
        for i in range(0, len(arr), batch_size):
            padded_seqs, seq_lens = self.pad_sentence_batch(arr[i:i+batch_size])
            yield padded_seqs, seq_lens

    def gen_batch(self, arr, batch_size):
        for i in range(0, len(arr), batch_size):
            yield arr[i: i+batch_size]

    def list_avg(self, l):
        return sum(l)/len(l)

    def decrease_lr(self, exp_decay, global_step, n_epoch, len_x, batch_size):
        if exp_decay:
            max_lr = 0.005
            min_lr = 0.001
            decay_rate = math.log(min_lr/max_lr) / (-n_epoch*len_x/batch_size)
            lr = max_lr*math.exp(-decay_rate*global_step)
        else:
            lr = 0.001
        return lr
